# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# #changing the working directory
# %cd /content/gdrive/My Drive/Kaggle
# #Check the present working directory using pwd command

# %% [markdown]
# Download data dibawah ini (1 Poin)<br>
# NIM Ganjil : (https://www.kaggle.com/gregorut/videogamesales) <br>
# NIM Genap : (https://www.kaggle.com/muthuj7/weather-dataset)

# %%
### tulis kode disini
# !kaggle datasets download -d muthuj7/weather-dataset

# %%
# !unzip \*.zip  && rm *.zip

# %% [markdown]
# import data tersebut sebagai dataframe **(2 Poin)**

# %%
import pandas as pd

# %%
### tulis kode disini
df = pd.read_csv("/content/gdrive/MyDrive/DataSets/healthcare.csv")
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# describe data tersebut **(10 Poin)** dan jelaskan pada asisten.

# %%
### tulis kode disini
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %% [markdown]
# Tampilkan head dan tail dari data tersebut **(5 Poin)**

# %%
### tulis kode disini
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %% [markdown]
# tampilkan nama column dari data tersebut **(2 Poin)**

# %%
### tulis kode disini
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
list(df.columns)
# Out:
# ['gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'ever_married',
#  'work_type',
#  'Residence_type',
#  'avg_glucose_level',
#  'bmi',
#  'smoking_status',
#  'stroke']

# %% [markdown]
# drop column yang tidak diperlukan, dan jelaskan kepada asisten kenapa kolom tersebut tidak diperlukan **(15 Poin)**

# %%
# ### tulis kode disini
# df_cleaned = df.drop(['Loud Cover'], axis=1)

# %% [markdown]
# tampilkan head data setelah ada kolom yang dihapus **(5 Poin)**

# %%
# ### tulis kode disini
# df_cleaned.head(2)

# %% [markdown]
# cek data apakah ada yang null **(5 Poin)**

# %%
### tulis kode disini
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# lakukan cleaning data, dan jelaskan pada asisten proses cleaning data tersebut **(20 Poin)**

# %%
dfcl = df.dropna(axis='rows')
# dfcl.head()
dfcl.isna().mean()
# Out:
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# stroke               0.0
# dtype: float64

# %% [markdown]
# tampilkan data setelah dilakukan cleaning **(5 Poin)**

# %%
### tulis kode disini
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
print('Jumlah record sebelum proses cleaning = ',df.shape[0])
print('Jumlah atribut sebelum proses cleaning= ',df.shape[1])
print('Jumlah record setelah proses cleaning = ',dfcl.shape[0])
print('Jumlah atribut setelah proses cleaning= ',dfcl.shape[1])
# Out:
# Jumlah record sebelum proses cleaning =  5110
# Jumlah atribut sebelum proses cleaning=  11
# Jumlah record setelah proses cleaning =  4909
# Jumlah atribut setelah proses cleaning=  11

# %% [markdown]
# analisis data tersebut, dan tampilkan minimal 3 chart dari data tersebut **(30 Poin)** serta jelaskan kepada asisten mengenai chart yang kalian buat dan informasi apa yang bisa kalian dapatkan

# %%
dfcl.hist(figsize=(15, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8cd3a5ddd0>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above18= dfcl[dfcl['age'] > 17.0]
plt.figure(figsize=(25,10))
sns.countplot(x= round(health_above18['age'],1),hue=health_above18['hypertension'])
plt.title("Frekuensi Hypertension Usia diatas 17 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Usia diatas 17 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above45= dfcl[dfcl['age'] > 45.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_above45['age'],1),hue=health_above45['hypertension'])
plt.title("Frekuensi Hypertension Usia diatas 45 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Usia diatas 45 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_bmi25= dfcl[dfcl['bmi'] > 25.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_bmi25['bmi'],1),hue=health_bmi25['hypertension'])
plt.title("Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above45= dfcl[dfcl['age'] > 45.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_above45['hypertension'],1),hue=health_above45['gender'])
plt.title("Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above45= dfcl[dfcl['age'] > 45.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_above45['hypertension'],1),hue=health_above45['smoking_status'])
plt.title("Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above45= dfcl[dfcl['age'] > 45.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_above45['heart_disease'],1),hue=health_above45['smoking_status'])
plt.title("Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above45= dfcl[dfcl['age'] > 45.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_above45['hypertension'],1),hue=health_above45['stroke'])
plt.title("Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above45= dfcl[dfcl['age'] > 45.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_above45['hypertension'],1),hue=health_above45['work_type'])
plt.title("Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
health_above45= dfcl[dfcl['age'] > 45.0]
plt.figure(figsize=(20,10))
sns.countplot(x= round(health_above45['hypertension'],1),hue=health_above45['work_type'])
plt.title("Frekuensi Hypertension Berdasarkan Gender Diatas 45 Tahun",fontsize=20)

# %%
dfcl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4909 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4909 non-null   int64
#  1   gender             4909 non-null   object
#  2   age                4909 non-null   float64
#  3   hypertension       4909 non-null   int64
#  4   heart_disease      4909 non-null   int64
#  5   ever_married       4909 non-null   object
#  6   work_type          4909 non-null   object
#  7   Residence_type     4909 non-null   object
#  8   avg_glucose_level  4909 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     4909 non-null   object
#  11  stroke             4909 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 627.6+ KB

# %%
# df_cleaned['Formatted Date'] = pd.to_datetime(df_cleaned['Formatted Date'], utc=True)
# df_cleaned = df_cleaned.set_index('Formatted Date')
# df_cleaned = df_cleaned.resample('M').mean()
# df_cleaned.head()

# %%
plt.figure(figsize = (14 , 6))
plt.title("Variasi Tempareture & Humidity per tahun (all month)")
plt.plot(dfcl[['hypertension', 'age']], marker = 'o')

# %%
sns.set_style("whitegrid")
sns.FacetGrid(dfcl, height=8).map(plt.scatter, "hypertension", "age")
plt.show()

# %%
sns.set_style("darkgrid")
sns.FacetGrid(dfcl, hue="age", height=10).map(sns.histplot, "bmi").add_legend()
plt.title("Analisis kondisi cuaca dengan temperature(C)")
